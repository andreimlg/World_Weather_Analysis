# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
#city = "Doha"
#city_url = url + "&q=" + city.replace(" ","+")
#city_weather = requests.get(city_url).json()
#city_description = city_weather["weather"][0]["description"]
#city_description
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=89d9c6217790a0d17f86969c13af87d4

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
       
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})


    except KeyError as e:
        print(f"{city.title()} city was not found. Skipping to the next...error {e}")
        pass


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | paros
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | aklavik
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | iguape
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | nenton
# Processing Record 11 of Set 1 | kita
# Processing Record 12 of Set 1 | shingu
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | ayan
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | lasa
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | pisco
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | nueva loja
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | trincomalee
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | taolanaro
# Taolanaro city was not found. Skipping to the next...error 'coord'
# Processing Record 26 of Set 1 | biltine
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | kuche
# Kuche city was not found. Skipping to the next...error 'coord'
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | port lincoln
# Processing Record 34 of Set 1 | bilma
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | amderma
# Amderma city was not found. Skipping to the next...error 'coord'
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | jiuquan
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | west point
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | banfora
# Processing Record 44 of Set 1 | cali
# Processing Record 45 of Set 1 | bathsheba
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | meiktila
# Processing Record 49 of Set 1 | sanmenxia
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | altayskoye
# Processing Record 2 of Set 2 | nizhneyansk
# Nizhneyansk city was not found. Skipping to the next...error 'coord'
# Processing Record 3 of Set 2 | lethem
# Processing Record 4 of Set 2 | klaksvik
# Processing Record 5 of Set 2 | rio gallegos
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | pitimbu
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | santa lucia
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | kuala terengganu
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | port-gentil
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | huaicheng
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | toowoomba
# Processing Record 24 of Set 2 | kununurra
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | cairns
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | kaeo
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | tucuman
# Processing Record 31 of Set 2 | shreveport
# Processing Record 32 of Set 2 | bor
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | malanje
# Processing Record 35 of Set 2 | mys shmidta
# Mys Shmidta city was not found. Skipping to the next...error 'coord'
# Processing Record 36 of Set 2 | santa isabel do rio negro
# Processing Record 37 of Set 2 | baykit
# Processing Record 38 of Set 2 | richards bay
# Processing Record 39 of Set 2 | sidi bu zayd
# Sidi Bu Zayd city was not found. Skipping to the next...error 'coord'
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | wanning
# Processing Record 42 of Set 2 | chicama
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | meulaboh
# Processing Record 45 of Set 2 | kalemie
# Processing Record 46 of Set 2 | oga
# Processing Record 47 of Set 2 | bambous virieux
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | sindor
# Processing Record 50 of Set 2 | marystown
# Processing Record 1 of Set 3 | mount gambier
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | fairbanks
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | mahibadhoo
# Processing Record 6 of Set 3 | starozhilovo
# Processing Record 7 of Set 3 | kazalinsk
# Kazalinsk city was not found. Skipping to the next...error 'coord'
# Processing Record 8 of Set 3 | villacarrillo
# Processing Record 9 of Set 3 | ciudad bolivar
# Processing Record 10 of Set 3 | olafsvik
# Processing Record 11 of Set 3 | attawapiskat
# Attawapiskat city was not found. Skipping to the next...error 'coord'
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | auki
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | bengkulu
# Processing Record 17 of Set 3 | fort nelson
# Processing Record 18 of Set 3 | biak
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | marawi
# Processing Record 21 of Set 3 | vaitupu
# Vaitupu city was not found. Skipping to the next...error 'coord'
# Processing Record 22 of Set 3 | lakatoro
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | dongsheng
# Processing Record 27 of Set 3 | burica
# Burica city was not found. Skipping to the next...error 'coord'
# Processing Record 28 of Set 3 | zhuanghe
# Processing Record 29 of Set 3 | morada nova
# Processing Record 30 of Set 3 | whitehorse
# Processing Record 31 of Set 3 | scottsburgh
# Scottsburgh city was not found. Skipping to the next...error 'coord'
# Processing Record 32 of Set 3 | turan
# Processing Record 33 of Set 3 | kalanguy
# Processing Record 34 of Set 3 | viedma
# Processing Record 35 of Set 3 | bandarbeyla
# Processing Record 36 of Set 3 | morehead
# Processing Record 37 of Set 3 | turukhansk
# Processing Record 38 of Set 3 | aranos
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | eagle pass
# Processing Record 41 of Set 3 | mareeba
# Processing Record 42 of Set 3 | dingolfing
# Processing Record 43 of Set 3 | borogontsy
# Processing Record 44 of Set 3 | tubruq
# Tubruq city was not found. Skipping to the next...error 'coord'
# Processing Record 45 of Set 3 | lazaro cardenas
# Processing Record 46 of Set 3 | margate
# Processing Record 47 of Set 3 | san vicente
# Processing Record 48 of Set 3 | yarmouth
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | pevek
# Processing Record 1 of Set 4 | kodarma
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | kamenskoye
# Kamenskoye city was not found. Skipping to the next...error 'coord'
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | kaohsiung
# Processing Record 6 of Set 4 | birao
# Processing Record 7 of Set 4 | marcona
# Marcona city was not found. Skipping to the next...error 'coord'
# Processing Record 8 of Set 4 | muzquiz
# Muzquiz city was not found. Skipping to the next...error 'coord'
# Processing Record 9 of Set 4 | liepaja
# Processing Record 10 of Set 4 | papetoai
# Processing Record 11 of Set 4 | karkaralinsk
# Karkaralinsk city was not found. Skipping to the next...error 'coord'
# Processing Record 12 of Set 4 | sibu
# Processing Record 13 of Set 4 | samusu
# Samusu city was not found. Skipping to the next...error 'coord'
# Processing Record 14 of Set 4 | annau
# Processing Record 15 of Set 4 | chapais
# Processing Record 16 of Set 4 | vrangel
# Processing Record 17 of Set 4 | gunjur
# Processing Record 18 of Set 4 | yola
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | paramonga
# Processing Record 21 of Set 4 | imeni babushkina
# Processing Record 22 of Set 4 | antalaha
# Processing Record 23 of Set 4 | kuusamo
# Processing Record 24 of Set 4 | gornopravdinsk
# Processing Record 25 of Set 4 | podyuga
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | berlevag
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | tessalit
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | jawhar
# Processing Record 32 of Set 4 | belushya guba
# Belushya Guba city was not found. Skipping to the next...error 'coord'
# Processing Record 33 of Set 4 | mandalgovi
# Processing Record 34 of Set 4 | wahran
# Wahran city was not found. Skipping to the next...error 'coord'
# Processing Record 35 of Set 4 | innisfail
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | alta floresta
# Processing Record 38 of Set 4 | kitimat
# Processing Record 39 of Set 4 | pokrovsk-uralskiy
# Pokrovsk-Uralskiy city was not found. Skipping to the next...error 'coord'
# Processing Record 40 of Set 4 | bay roberts
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | temple
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | cheuskiny
# Cheuskiny city was not found. Skipping to the next...error 'coord'
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | melong
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | khani
# Processing Record 50 of Set 4 | kondagaon
# Processing Record 1 of Set 5 | salinas
# Processing Record 2 of Set 5 | warqla
# Warqla city was not found. Skipping to the next...error 'coord'
# Processing Record 3 of Set 5 | port elizabeth
# Processing Record 4 of Set 5 | mill valley
# Processing Record 5 of Set 5 | vardo
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | hinton
# Processing Record 8 of Set 5 | gulshat
# Gulshat city was not found. Skipping to the next...error 'coord'
# Processing Record 9 of Set 5 | sandy bay
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | ripoll
# Processing Record 12 of Set 5 | springfield
# Processing Record 13 of Set 5 | papara
# Processing Record 14 of Set 5 | san carlos de bariloche
# Processing Record 15 of Set 5 | poum
# Processing Record 16 of Set 5 | khyriv
# Processing Record 17 of Set 5 | illoqqortoormiut
# Illoqqortoormiut city was not found. Skipping to the next...error 'coord'
# Processing Record 18 of Set 5 | kirovskiy
# Processing Record 19 of Set 5 | barentsburg
# Barentsburg city was not found. Skipping to the next...error 'coord'
# Processing Record 20 of Set 5 | sao pedro do sul
# Processing Record 21 of Set 5 | marienburg
# Processing Record 22 of Set 5 | lolua
# Lolua city was not found. Skipping to the next...error 'coord'
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | eureka
# Processing Record 25 of Set 5 | krasnovishersk
# Processing Record 26 of Set 5 | rafaela
# Processing Record 27 of Set 5 | almaznyy
# Processing Record 28 of Set 5 | yarensk
# Processing Record 29 of Set 5 | lincoln
# Processing Record 30 of Set 5 | college
# Processing Record 31 of Set 5 | oranjemund
# Processing Record 32 of Set 5 | gizo
# Processing Record 33 of Set 5 | waingapu
# Processing Record 34 of Set 5 | flin flon
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | te anau
# Processing Record 37 of Set 5 | leirvik
# Processing Record 38 of Set 5 | colares
# Processing Record 39 of Set 5 | cayenne
# Processing Record 40 of Set 5 | dukat
# Processing Record 41 of Set 5 | tual
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | kamenka
# Processing Record 44 of Set 5 | rocha
# Processing Record 45 of Set 5 | mezen
# Processing Record 46 of Set 5 | gogrial
# Processing Record 47 of Set 5 | beloha
# Processing Record 48 of Set 5 | kapaa
# Processing Record 49 of Set 5 | darhan
# Processing Record 50 of Set 5 | vao
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | puerto ayora
# Processing Record 3 of Set 6 | aksu
# Processing Record 4 of Set 6 | corning
# Processing Record 5 of Set 6 | puerto carreno
# Processing Record 6 of Set 6 | nouadhibou
# Processing Record 7 of Set 6 | fallon
# Processing Record 8 of Set 6 | shima
# Processing Record 9 of Set 6 | broken hill
# Processing Record 10 of Set 6 | yotoco
# Processing Record 11 of Set 6 | khor
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | baykalsk
# Processing Record 14 of Set 6 | sadri
# Processing Record 15 of Set 6 | carnarvon
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | tambovka
# Processing Record 18 of Set 6 | bolshoye ignatovo
# Bolshoye Ignatovo city was not found. Skipping to the next...error 'coord'
# Processing Record 19 of Set 6 | corsicana
# Processing Record 20 of Set 6 | saskylakh
# Processing Record 21 of Set 6 | torbat-e jam
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | rio claro
# Processing Record 24 of Set 6 | ambulu
# Processing Record 25 of Set 6 | teknaf
# Processing Record 26 of Set 6 | seaham
# Processing Record 27 of Set 6 | astoria
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | sataua
# Sataua city was not found. Skipping to the next...error 'coord'
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | marsh harbour
# Processing Record 33 of Set 6 | dauphin
# Processing Record 34 of Set 6 | sioux lookout
# Processing Record 35 of Set 6 | weihai
# Processing Record 36 of Set 6 | tumannyy
# Tumannyy city was not found. Skipping to the next...error 'coord'
# Processing Record 37 of Set 6 | praia da vitoria
# Processing Record 38 of Set 6 | whitianga
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | terra santa
# Processing Record 41 of Set 6 | murgab
# Processing Record 42 of Set 6 | porto belo
# Processing Record 43 of Set 6 | severo-kurilsk
# Processing Record 44 of Set 6 | dwarka
# Processing Record 45 of Set 6 | yar-sale
# Processing Record 46 of Set 6 | urumqi
# Processing Record 47 of Set 6 | itarema
# Processing Record 48 of Set 6 | muros
# Processing Record 49 of Set 6 | bosaso
# Processing Record 50 of Set 6 | kilindoni
# Processing Record 1 of Set 7 | mugur-aksy
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | lemoore
# Processing Record 4 of Set 7 | taoudenni
# Processing Record 5 of Set 7 | faya
# Processing Record 6 of Set 7 | bukan
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | manggar
# Processing Record 9 of Set 7 | puerto escondido
# Processing Record 10 of Set 7 | aginskoye
# Processing Record 11 of Set 7 | souillac
# Processing Record 12 of Set 7 | kashan
# Processing Record 13 of Set 7 | nioro
# Processing Record 14 of Set 7 | paamiut
# Processing Record 15 of Set 7 | haines junction
# Processing Record 16 of Set 7 | trorod
# Processing Record 17 of Set 7 | cherskiy
# Processing Record 18 of Set 7 | de-kastri
# Processing Record 19 of Set 7 | coolum beach
# Processing Record 20 of Set 7 | norman wells
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | roma
# Processing Record 24 of Set 7 | mezhdurechensk
# Processing Record 25 of Set 7 | acajutla
# Processing Record 26 of Set 7 | sentyabrskiy
# Sentyabrskiy city was not found. Skipping to the next...error 'coord'
# Processing Record 27 of Set 7 | bang saphan
# Processing Record 28 of Set 7 | alexandria
# Processing Record 29 of Set 7 | dok kham tai
# Processing Record 30 of Set 7 | achisay
# Achisay city was not found. Skipping to the next...error 'coord'
# Processing Record 31 of Set 7 | hervey bay
# Processing Record 32 of Set 7 | bridgetown
# Processing Record 33 of Set 7 | aksarka
# Processing Record 34 of Set 7 | honiara
# Processing Record 35 of Set 7 | erlenbach
# Processing Record 36 of Set 7 | marseille
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | mentok
# Mentok city was not found. Skipping to the next...error 'coord'
# Processing Record 39 of Set 7 | byron bay
# Processing Record 40 of Set 7 | grand centre
# Grand Centre city was not found. Skipping to the next...error 'coord'
# Processing Record 41 of Set 7 | fonte boa
# Processing Record 42 of Set 7 | sabha
# Processing Record 43 of Set 7 | soe
# Processing Record 44 of Set 7 | ostrovnoy
# Processing Record 45 of Set 7 | kutum
# Processing Record 46 of Set 7 | tilichiki
# Processing Record 47 of Set 7 | batagay-alyta
# Processing Record 48 of Set 7 | rungata
# Rungata city was not found. Skipping to the next...error 'coord'
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | concordia
# Processing Record 1 of Set 8 | vargashi
# Processing Record 2 of Set 8 | boffa
# Processing Record 3 of Set 8 | sao filipe
# Processing Record 4 of Set 8 | gurgan
# Gurgan city was not found. Skipping to the next...error 'coord'
# Processing Record 5 of Set 8 | torbay
# Processing Record 6 of Set 8 | le vauclin
# Processing Record 7 of Set 8 | arica
# Processing Record 8 of Set 8 | korla
# Processing Record 9 of Set 8 | shache
# Processing Record 10 of Set 8 | arrecife
# Processing Record 11 of Set 8 | salinopolis
# Processing Record 12 of Set 8 | nador
# Processing Record 13 of Set 8 | semnan
# Processing Record 14 of Set 8 | katsuura
# Processing Record 15 of Set 8 | vedaranniyam
# Vedaranniyam city was not found. Skipping to the next...error 'coord'
# Processing Record 16 of Set 8 | dalbandin
# Processing Record 17 of Set 8 | port shepstone
# Processing Record 18 of Set 8 | yanaul
# Processing Record 19 of Set 8 | hualmay
# Processing Record 20 of Set 8 | banda aceh
# Processing Record 21 of Set 8 | benjamin constant
# Processing Record 22 of Set 8 | ixtapa
# Processing Record 23 of Set 8 | verkhniy fiagdon
# Processing Record 24 of Set 8 | plettenberg bay
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | winslow
# Processing Record 27 of Set 8 | sabang
# Processing Record 28 of Set 8 | rawson
# Processing Record 29 of Set 8 | tubuala
# Processing Record 30 of Set 8 | padang
# Processing Record 31 of Set 8 | sangar
# Processing Record 32 of Set 8 | jumla
# Processing Record 33 of Set 8 | ksenyevka
# Ksenyevka city was not found. Skipping to the next...error 'coord'
# Processing Record 34 of Set 8 | lata
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | tefe
# Processing Record 37 of Set 8 | barawe
# Barawe city was not found. Skipping to the next...error 'coord'
# Processing Record 38 of Set 8 | bontang
# Processing Record 39 of Set 8 | chokurdakh
# Processing Record 40 of Set 8 | longyearbyen
# Processing Record 41 of Set 8 | skibbereen
# Processing Record 42 of Set 8 | esil
# Processing Record 43 of Set 8 | mildura
# Processing Record 44 of Set 8 | amberley
# Processing Record 45 of Set 8 | antsohihy
# Processing Record 46 of Set 8 | kenai
# Processing Record 47 of Set 8 | palabuhanratu
# Palabuhanratu city was not found. Skipping to the next...error 'coord'
# Processing Record 48 of Set 8 | okhotsk
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | mocuba
# Processing Record 1 of Set 9 | bati
# Processing Record 2 of Set 9 | prainha
# Processing Record 3 of Set 9 | flinders
# Processing Record 4 of Set 9 | soyo
# Processing Record 5 of Set 9 | karratha
# Processing Record 6 of Set 9 | moussoro
# Processing Record 7 of Set 9 | pangnirtung
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | harrisburg
# Processing Record 10 of Set 9 | utiroa
# Utiroa city was not found. Skipping to the next...error 'coord'
# Processing Record 11 of Set 9 | dicabisagan
# Processing Record 12 of Set 9 | lewistown
# Processing Record 13 of Set 9 | rafraf
# Processing Record 14 of Set 9 | tshela
# Processing Record 15 of Set 9 | mahon
# Processing Record 16 of Set 9 | stadtbergen
# Processing Record 17 of Set 9 | ryotsu
# Processing Record 18 of Set 9 | trang
# Processing Record 19 of Set 9 | culebra
# Processing Record 20 of Set 9 | jardim
# Processing Record 21 of Set 9 | cabo san lucas
# Processing Record 22 of Set 9 | solnechnyy
# Processing Record 23 of Set 9 | traverse city
# Processing Record 24 of Set 9 | sibolga
# Processing Record 25 of Set 9 | nemuro
# Processing Record 26 of Set 9 | srednekolymsk
# Processing Record 27 of Set 9 | gao
# Processing Record 28 of Set 9 | berdigestyakh
# Processing Record 29 of Set 9 | boende
# Processing Record 30 of Set 9 | vila franca do campo
# Processing Record 31 of Set 9 | san pedro
# Processing Record 32 of Set 9 | palmer
# Processing Record 33 of Set 9 | saleaula
# Saleaula city was not found. Skipping to the next...error 'coord'
# Processing Record 34 of Set 9 | shimanovsk
# Processing Record 35 of Set 9 | jinchengjiang
# Jinchengjiang city was not found. Skipping to the next...error 'coord'
# Processing Record 36 of Set 9 | shakawe
# Processing Record 37 of Set 9 | port hawkesbury
# Processing Record 38 of Set 9 | sinnamary
# Processing Record 39 of Set 9 | teshie
# Processing Record 40 of Set 9 | qeshm
# Processing Record 41 of Set 9 | iqaluit
# Processing Record 42 of Set 9 | grand river south east
# Grand River South East city was not found. Skipping to the next...error 'coord'
# Processing Record 43 of Set 9 | campo formoso
# Processing Record 44 of Set 9 | morristown
# Processing Record 45 of Set 9 | boddam
# Processing Record 46 of Set 9 | dobric
# Processing Record 47 of Set 9 | batouri
# Processing Record 48 of Set 9 | farah
# Processing Record 49 of Set 9 | purwodadi
# Processing Record 50 of Set 9 | omboue
# Processing Record 1 of Set 10 | necochea
# Processing Record 2 of Set 10 | linqiong
# Processing Record 3 of Set 10 | gondanglegi
# Processing Record 4 of Set 10 | hovd
# Processing Record 5 of Set 10 | vanavara
# Processing Record 6 of Set 10 | northam
# Processing Record 7 of Set 10 | tsihombe
# Tsihombe city was not found. Skipping to the next...error 'coord'
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | medzilaborce
# Processing Record 10 of Set 10 | chihuahua
# Processing Record 11 of Set 10 | strazske
# Processing Record 12 of Set 10 | birnin kebbi
# Processing Record 13 of Set 10 | elko
# Processing Record 14 of Set 10 | christchurch
# Processing Record 15 of Set 10 | salalah
# Processing Record 16 of Set 10 | gallup
# Processing Record 17 of Set 10 | beni mazar
# Processing Record 18 of Set 10 | susehri
# Processing Record 19 of Set 10 | isabela
# Processing Record 20 of Set 10 | pimenta bueno
# Processing Record 21 of Set 10 | grand-santi
# Processing Record 22 of Set 10 | santa rita
# Processing Record 23 of Set 10 | poya
# Processing Record 24 of Set 10 | karlskrona
# Processing Record 25 of Set 10 | nanakuli
# Processing Record 26 of Set 10 | carutapera
# Processing Record 27 of Set 10 | cururupu
# Processing Record 28 of Set 10 | smidovich
# Processing Record 29 of Set 10 | vryburg
# Processing Record 30 of Set 10 | chadiza
# Processing Record 31 of Set 10 | san patricio
# Processing Record 32 of Set 10 | aripuana
# Processing Record 33 of Set 10 | alice springs
# Processing Record 34 of Set 10 | guanare
# Processing Record 35 of Set 10 | providencia
# Processing Record 36 of Set 10 | kyren
# Processing Record 37 of Set 10 | dzhalil
# Processing Record 38 of Set 10 | belaya gora
# Processing Record 39 of Set 10 | ilhabela
# Processing Record 40 of Set 10 | pemba
# Processing Record 41 of Set 10 | nome
# Processing Record 42 of Set 10 | tuy hoa
# Processing Record 43 of Set 10 | araouane
# Processing Record 44 of Set 10 | douentza
# Processing Record 45 of Set 10 | emerald
# Processing Record 46 of Set 10 | sorvag
# Sorvag city was not found. Skipping to the next...error 'coord'
# Processing Record 47 of Set 10 | saint-louis
# Processing Record 48 of Set 10 | bukachacha
# Processing Record 49 of Set 10 | broome
# Processing Record 50 of Set 10 | kerema
# Processing Record 1 of Set 11 | halalo
# Halalo city was not found. Skipping to the next...error 'coord'
# Processing Record 2 of Set 11 | susanville
# Processing Record 3 of Set 11 | sao sebastiao
# Processing Record 4 of Set 11 | reconquista
# Processing Record 5 of Set 11 | bileca
# Processing Record 6 of Set 11 | gamba
# Processing Record 7 of Set 11 | san jose iturbide
# Processing Record 8 of Set 11 | san quintin
# Processing Record 9 of Set 11 | saryozek
# Processing Record 10 of Set 11 | black river
# Processing Record 11 of Set 11 | nokaneng
# Processing Record 12 of Set 11 | kifri
# Processing Record 13 of Set 11 | savannah bight
# Processing Record 14 of Set 11 | chimoio
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | shubarkuduk
# Processing Record 17 of Set 11 | saint-esteve
# Processing Record 18 of Set 11 | stamsund
# Stamsund city was not found. Skipping to the next...error 'coord'
# Processing Record 19 of Set 11 | palimbang
# Processing Record 20 of Set 11 | los llanos de aridane
# Processing Record 21 of Set 11 | bayburt
# Processing Record 22 of Set 11 | fortuna
# Processing Record 23 of Set 11 | furano
# Processing Record 24 of Set 11 | kiunga
# Processing Record 25 of Set 11 | vestmannaeyjar
# Processing Record 26 of Set 11 | yenotayevka
# Processing Record 27 of Set 11 | brownsville
# Processing Record 28 of Set 11 | gisborne
# Processing Record 29 of Set 11 | guerrero negro
# Processing Record 30 of Set 11 | siocon
# Processing Record 31 of Set 11 | chhagalnaiya
# Processing Record 32 of Set 11 | haapiti
# Processing Record 33 of Set 11 | gamboula
# Processing Record 34 of Set 11 | charters towers
# Processing Record 35 of Set 11 | dongning
# Processing Record 36 of Set 11 | floro
# Processing Record 37 of Set 11 | matara
# Processing Record 38 of Set 11 | kirakira
# Processing Record 39 of Set 11 | west bay
# Processing Record 40 of Set 11 | nikolskoye-na-cheremshane
# Nikolskoye-Na-Cheremshane city was not found. Skipping to the next...error 'coord'
# Processing Record 41 of Set 11 | cap malheureux
# Processing Record 42 of Set 11 | lorengau
# Processing Record 43 of Set 11 | seoul
# Processing Record 44 of Set 11 | meyungs
# Meyungs city was not found. Skipping to the next...error 'coord'
# Processing Record 45 of Set 11 | comodoro rivadavia
# Processing Record 46 of Set 11 | banjar
# Processing Record 47 of Set 11 | shuangcheng
# Processing Record 48 of Set 11 | orangeburg
# Processing Record 49 of Set 11 | bonavista
# Processing Record 50 of Set 11 | aransas pass
# Processing Record 1 of Set 12 | praya
# Processing Record 2 of Set 12 | ahuimanu
# Processing Record 3 of Set 12 | high rock
# Processing Record 4 of Set 12 | torri di quartesolo
# Processing Record 5 of Set 12 | buluang
# Processing Record 6 of Set 12 | immenstadt
# Processing Record 7 of Set 12 | oksfjord
# Processing Record 8 of Set 12 | umzimvubu
# Umzimvubu city was not found. Skipping to the next...error 'coord'
# Processing Record 9 of Set 12 | vilhena
# Processing Record 10 of Set 12 | port macquarie
# Processing Record 11 of Set 12 | sola
# Processing Record 12 of Set 12 | progreso
# Processing Record 13 of Set 12 | hanna
# Processing Record 14 of Set 12 | gazi
# Processing Record 15 of Set 12 | tirumullaivasal
# Processing Record 16 of Set 12 | doha
# Processing Record 17 of Set 12 | tura
# Processing Record 18 of Set 12 | ratnagiri
# Processing Record 19 of Set 12 | tezu
# Processing Record 20 of Set 12 | lewisville
# Processing Record 21 of Set 12 | vila velha
# Processing Record 22 of Set 12 | safaga
# Processing Record 23 of Set 12 | mpanda
# Processing Record 24 of Set 12 | druskininkai
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | bere
# Processing Record 27 of Set 12 | winkler
# Processing Record 28 of Set 12 | zhigalovo
# Processing Record 29 of Set 12 | meadow lake
# Processing Record 30 of Set 12 | corinto
# Processing Record 31 of Set 12 | uribia
# Processing Record 32 of Set 12 | chipinge
# Processing Record 33 of Set 12 | pacific grove
# Processing Record 34 of Set 12 | port hedland
# Processing Record 35 of Set 12 | matamoros
# Processing Record 36 of Set 12 | sungairaya
# Processing Record 37 of Set 12 | kieta
# Processing Record 38 of Set 12 | sakakah
# Processing Record 39 of Set 12 | el balyana
# El Balyana city was not found. Skipping to the next...error 'coord'
# Processing Record 40 of Set 12 | dakar
# Processing Record 41 of Set 12 | sedro-woolley
# Processing Record 42 of Set 12 | qaqortoq
# Processing Record 43 of Set 12 | skjervoy
# Processing Record 44 of Set 12 | morondava
# Processing Record 45 of Set 12 | trairi
# Processing Record 46 of Set 12 | joensuu
# Processing Record 47 of Set 12 | samarai
# Processing Record 48 of Set 12 | solovetskiy
# Solovetskiy city was not found. Skipping to the next...error 'coord'
# Processing Record 49 of Set 12 | rodniki
# Processing Record 50 of Set 12 | tawnat
# Tawnat city was not found. Skipping to the next...error 'coord'
# Processing Record 1 of Set 13 | forestville
# Processing Record 2 of Set 13 | sovetskaya gavan
# Processing Record 3 of Set 13 | bandar-e lengeh
# Processing Record 4 of Set 13 | ust-ilimsk
# Processing Record 5 of Set 13 | nautanwa
# Processing Record 6 of Set 13 | borovskoy
# Processing Record 7 of Set 13 | hofn
# Processing Record 8 of Set 13 | jalu
# Processing Record 9 of Set 13 | doka
# Processing Record 10 of Set 13 | baneh
# Processing Record 11 of Set 13 | alofi
# Processing Record 12 of Set 13 | huntsville
# Processing Record 13 of Set 13 | hope
# Processing Record 14 of Set 13 | teguise
# Processing Record 15 of Set 13 | kampli
# Processing Record 16 of Set 13 | dhidhdhoo
# Processing Record 17 of Set 13 | leshukonskoye
# Processing Record 18 of Set 13 | svetlyy
# Processing Record 19 of Set 13 | nova prata
# Processing Record 20 of Set 13 | zhigansk
# Processing Record 21 of Set 13 | najran
# Processing Record 22 of Set 13 | neuquen
# Processing Record 23 of Set 13 | harnosand
# Processing Record 24 of Set 13 | saint-francois
# Processing Record 25 of Set 13 | lakselv
# Processing Record 26 of Set 13 | orlik
# Processing Record 27 of Set 13 | santa maria
# Processing Record 28 of Set 13 | buraydah
# Processing Record 29 of Set 13 | havre-saint-pierre
# Processing Record 30 of Set 13 | satitoa
# Satitoa city was not found. Skipping to the next...error 'coord'
# Processing Record 31 of Set 13 | derzhavinsk
# Processing Record 32 of Set 13 | chadan
# Processing Record 33 of Set 13 | merauke
# Processing Record 34 of Set 13 | tibati
# Processing Record 35 of Set 13 | kasama
# Processing Record 36 of Set 13 | guerrero
# Processing Record 37 of Set 13 | henties bay
# Processing Record 38 of Set 13 | vilyuysk
# Processing Record 39 of Set 13 | saint-georges
# Processing Record 40 of Set 13 | kudahuvadhoo
# Processing Record 41 of Set 13 | arauco
# Processing Record 42 of Set 13 | walvis bay
# Processing Record 43 of Set 13 | bolungarvik
# Bolungarvik city was not found. Skipping to the next...error 'coord'
# Processing Record 44 of Set 13 | batagay
# Processing Record 45 of Set 13 | mayo
# Processing Record 46 of Set 13 | roebourne
# Processing Record 47 of Set 13 | sao joaquim
# Processing Record 48 of Set 13 | alotau
# Alotau city was not found. Skipping to the next...error 'coord'
# Processing Record 49 of Set 13 | tupancireta
# Processing Record 50 of Set 13 | kichera
# Processing Record 1 of Set 14 | normal
# Processing Record 2 of Set 14 | yueyang
# Processing Record 3 of Set 14 | suluq
# Processing Record 4 of Set 14 | novodugino
# Processing Record 5 of Set 14 | tambopata
# Processing Record 6 of Set 14 | wilmington
# Processing Record 7 of Set 14 | tiznit
# Processing Record 8 of Set 14 | tuatapere
# Processing Record 9 of Set 14 | saint-joseph
# Processing Record 10 of Set 14 | mago
# Processing Record 11 of Set 14 | naze
# Processing Record 12 of Set 14 | show low
# Processing Record 13 of Set 14 | belyy yar
# Processing Record 14 of Set 14 | venado tuerto
# Processing Record 15 of Set 14 | nara
# Processing Record 16 of Set 14 | yining
# Processing Record 17 of Set 14 | koutiala
# Processing Record 18 of Set 14 | bongandanga
# Processing Record 19 of Set 14 | ponta delgada
# Processing Record 20 of Set 14 | kochevo
# Processing Record 21 of Set 14 | mehamn
# Processing Record 22 of Set 14 | bousse
# Processing Record 23 of Set 14 | half moon bay
# Processing Record 24 of Set 14 | antofagasta
# Processing Record 25 of Set 14 | chara
# Processing Record 26 of Set 14 | south yuba city
# Processing Record 27 of Set 14 | bethanien
# Processing Record 28 of Set 14 | cayeli
# Processing Record 29 of Set 14 | shchelyayur
# Shchelyayur city was not found. Skipping to the next...error 'coord'
# Processing Record 30 of Set 14 | bubaque
# Processing Record 31 of Set 14 | hoi an
# Processing Record 32 of Set 14 | edd
# Processing Record 33 of Set 14 | marquette
# Processing Record 34 of Set 14 | novaya igirma
# Processing Record 35 of Set 14 | mega
# Processing Record 36 of Set 14 | san lawrenz
# Processing Record 37 of Set 14 | kologriv
# Processing Record 38 of Set 14 | palu
# Processing Record 39 of Set 14 | kosh-agach
# Processing Record 40 of Set 14 | panaba
# Processing Record 41 of Set 14 | maraba
# Processing Record 42 of Set 14 | galle
# Processing Record 43 of Set 14 | barra dos coqueiros
# Processing Record 44 of Set 14 | bhatkal
# Processing Record 45 of Set 14 | bargal
# Bargal city was not found. Skipping to the next...error 'coord'
# Processing Record 46 of Set 14 | rundu
# Processing Record 47 of Set 14 | deputatskiy
# Processing Record 48 of Set 14 | taltal
# Processing Record 49 of Set 14 | zyryanka
# Processing Record 50 of Set 14 | benghazi
# Processing Record 1 of Set 15 | dahuk
# Processing Record 2 of Set 15 | okha
# Processing Record 3 of Set 15 | kawalu
# Processing Record 4 of Set 15 | passo de camaragibe
# Processing Record 5 of Set 15 | narsaq
# Processing Record 6 of Set 15 | davila
# Processing Record 7 of Set 15 | chervishevo
# Processing Record 8 of Set 15 | kralendijk
# Processing Record 9 of Set 15 | ponnani
# Processing Record 10 of Set 15 | tromso
# Processing Record 11 of Set 15 | bayshore gardens
# Processing Record 12 of Set 15 | hay river
# Processing Record 13 of Set 15 | caravelas
# Processing Record 14 of Set 15 | prince rupert
# Processing Record 15 of Set 15 | port moresby
# Processing Record 16 of Set 15 | porirua
# Processing Record 17 of Set 15 | marzuq
# Processing Record 18 of Set 15 | zhangye
# Processing Record 19 of Set 15 | benoy
# Processing Record 20 of Set 15 | teguldet
# Processing Record 21 of Set 15 | berezovyy
# Processing Record 22 of Set 15 | barcelona
# Processing Record 23 of Set 15 | abu jubayhah
# Abu Jubayhah city was not found. Skipping to the next...error 'coord'
# Processing Record 24 of Set 15 | sidi ali
# Processing Record 25 of Set 15 | nyanguge
# Processing Record 26 of Set 15 | buzmeyin
# Processing Record 27 of Set 15 | dawei
# Processing Record 28 of Set 15 | nishihara
# Processing Record 29 of Set 15 | ugoofaaru
# Processing Record 30 of Set 15 | turtkul
# Turtkul city was not found. Skipping to the next...error 'coord'
# Processing Record 31 of Set 15 | kurilsk
# Processing Record 32 of Set 15 | aflu
# Aflu city was not found. Skipping to the next...error 'coord'
# Processing Record 33 of Set 15 | vorobyevka
# Processing Record 34 of Set 15 | voh
# Processing Record 35 of Set 15 | brae
# Processing Record 36 of Set 15 | porto novo
# Processing Record 37 of Set 15 | the pas
# Processing Record 38 of Set 15 | veinticinco de mayo
# Processing Record 39 of Set 15 | catamarca
# Processing Record 40 of Set 15 | maua
# Processing Record 41 of Set 15 | laiagam
# Laiagam city was not found. Skipping to the next...error 'coord'
# Processing Record 42 of Set 15 | cam ranh
# Processing Record 43 of Set 15 | tazovskiy
# Processing Record 44 of Set 15 | bury saint edmunds
# Bury Saint Edmunds city was not found. Skipping to the next...error 'coord'
# Processing Record 45 of Set 15 | akkermanovka
# Processing Record 46 of Set 15 | mahina
# Processing Record 47 of Set 15 | loukhi
# Processing Record 48 of Set 15 | nelson bay
# Processing Record 49 of Set 15 | ust-koksa
# Processing Record 50 of Set 15 | el jicaro
# Processing Record 1 of Set 16 | rovnoye
# Processing Record 2 of Set 16 | camacha
# Processing Record 3 of Set 16 | bathurst
# Processing Record 4 of Set 16 | ardu
# Processing Record 5 of Set 16 | cockburn town
# Processing Record 6 of Set 16 | amahai
# Processing Record 7 of Set 16 | gat
# Processing Record 8 of Set 16 | ginir
# Processing Record 9 of Set 16 | kilakarai
# Processing Record 10 of Set 16 | gornyy
# Processing Record 11 of Set 16 | muroto
# Processing Record 12 of Set 16 | uyemskiy
# Processing Record 13 of Set 16 | shimoda
# Processing Record 14 of Set 16 | pelasyia
# Pelasyia city was not found. Skipping to the next...error 'coord'
# Processing Record 15 of Set 16 | kavaratti
# Processing Record 16 of Set 16 | shwebo
# Processing Record 17 of Set 16 | superior
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Barrow      US  71.2906 -156.7887    -27.38        68           0
# 1        Paros      GR  37.0833   25.1500     54.30        66          61
# 2   Kaitangata      NZ -46.2817  169.8464     59.94        72          99
# 3      Aklavik      CA  68.2191 -135.0107    -24.77        97         100
# 4       Atuona      PF  -9.8000 -139.0333     77.32        80          20
# 5  Provideniya      RU  64.3833 -173.3000     -5.69        65           0
# 6    Jamestown      US  42.0970  -79.2353     15.12        72         100
# 7       Iguape      BR -24.7081  -47.5553     71.96        93           8
# 8    Upernavik      GL  72.7868  -56.1549      3.83        92         100
# 9       Nenton      GT  15.8000  -91.7500     71.76        84         100
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1       19.57       broken clouds
# 2        7.29     overcast clouds
# 3       11.74     overcast clouds
# 4       13.96          light rain
# 5       11.18           clear sky
# 6        3.44     overcast clouds
# 7        4.81           clear sky
# 8       29.15          light snow
# 9        4.68     overcast clouds

# %%
len(city_data)
# Out:
# 703

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
