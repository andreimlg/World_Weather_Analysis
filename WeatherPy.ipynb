# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=89d9c6217790a0d17f86969c13af87d4

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vestmannaeyjar
# Processing Record 2 of Set 1 | poronaysk
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 1 | norman wells
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | la ronge
# Processing Record 10 of Set 1 | aracaju
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | ancud
# Processing Record 13 of Set 1 | laizhou
# Processing Record 14 of Set 1 | hofn
# Processing Record 15 of Set 1 | berdigestyakh
# Processing Record 16 of Set 1 | svetlogorsk
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | pilar
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | prince rupert
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bin qirdan
# Processing Record 34 of Set 1 | srednekolymsk
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | stepnyak
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | wewak
# Processing Record 39 of Set 1 | kovdor
# Processing Record 40 of Set 1 | brae
# Processing Record 41 of Set 1 | key west
# Processing Record 42 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 1 | wanaka
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | katobu
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | waitara
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | tual
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | bilibino
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | wabana
# Processing Record 9 of Set 2 | komsomolets
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | murray bridge
# Processing Record 13 of Set 2 | makat
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | wajima
# Processing Record 17 of Set 2 | huron
# Processing Record 18 of Set 2 | atar
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | ilheus
# Processing Record 21 of Set 2 | jibuti
# Processing Record 22 of Set 2 | banjarmasin
# Processing Record 23 of Set 2 | thunder bay
# Processing Record 24 of Set 2 | baykit
# Processing Record 25 of Set 2 | nuuk
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | kozlovka
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | kurilsk
# Processing Record 33 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | turbat
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | kawalu
# Processing Record 40 of Set 2 | kahului
# Processing Record 41 of Set 2 | mabaruma
# Processing Record 42 of Set 2 | diplo
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | canico
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | alyangula
# Processing Record 50 of Set 2 | nabinagar
# Processing Record 1 of Set 3 | kapit
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | bengkulu
# Processing Record 4 of Set 3 | alipur
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | shablykino
# Processing Record 9 of Set 3 | kamenka
# Processing Record 10 of Set 3 | antofagasta
# Processing Record 11 of Set 3 | koutiala
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | tessalit
# Processing Record 15 of Set 3 | caravelas
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | lisala
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | kavieng
# Processing Record 20 of Set 3 | aksarka
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | udachnyy
# Processing Record 23 of Set 3 | orumiyeh
# Processing Record 24 of Set 3 | massakory
# Processing Record 25 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 3 | camacha
# Processing Record 27 of Set 3 | gryazovets
# Processing Record 28 of Set 3 | oranjemund
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | havre-saint-pierre
# Processing Record 31 of Set 3 | ketchikan
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | andra
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | anadyr
# Processing Record 42 of Set 3 | xudat
# Processing Record 43 of Set 3 | brookhaven
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | stavropol
# Processing Record 46 of Set 3 | praia da vitoria
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 3 | tytuvenai
# Processing Record 50 of Set 3 | cockburn town
# Processing Record 1 of Set 4 | vanavara
# Processing Record 2 of Set 4 | rio grande
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | buin
# Processing Record 5 of Set 4 | pahuatlan
# City not found. Skipping...
# Processing Record 6 of Set 4 | keetmanshoop
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | mawlaik
# Processing Record 10 of Set 4 | suntar
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | new norfolk
# Processing Record 13 of Set 4 | biak
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | genhe
# Processing Record 17 of Set 4 | lieksa
# Processing Record 18 of Set 4 | dunedin
# Processing Record 19 of Set 4 | ahuimanu
# Processing Record 20 of Set 4 | port keats
# Processing Record 21 of Set 4 | palmerston
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | orange cove
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | grand-lahou
# Processing Record 26 of Set 4 | belaya gora
# Processing Record 27 of Set 4 | graaff-reinet
# Processing Record 28 of Set 4 | baudh
# Processing Record 29 of Set 4 | paamiut
# Processing Record 30 of Set 4 | kutum
# Processing Record 31 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 4 | riyadh
# Processing Record 33 of Set 4 | crib point
# Processing Record 34 of Set 4 | middle valley
# Processing Record 35 of Set 4 | barra bonita
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | hima
# Processing Record 38 of Set 4 | miyako
# Processing Record 39 of Set 4 | mwinilunga
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | pincher creek
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | gazanjyk
# Processing Record 44 of Set 4 | kijang
# Processing Record 45 of Set 4 | imperia
# Processing Record 46 of Set 4 | comodoro rivadavia
# Processing Record 47 of Set 4 | posse
# Processing Record 48 of Set 4 | almaty
# Processing Record 49 of Set 4 | kurumkan
# Processing Record 50 of Set 4 | kjollefjord
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | sal rei
# Processing Record 3 of Set 5 | swan hill
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | breytovo
# Processing Record 6 of Set 5 | portland
# Processing Record 7 of Set 5 | dryden
# Processing Record 8 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 5 | honningsvag
# Processing Record 10 of Set 5 | agadir
# Processing Record 11 of Set 5 | batangafo
# Processing Record 12 of Set 5 | beitbridge
# Processing Record 13 of Set 5 | bambous virieux
# Processing Record 14 of Set 5 | san narciso
# Processing Record 15 of Set 5 | palafrugell
# Processing Record 16 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 5 | isangel
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | mount isa
# Processing Record 21 of Set 5 | katrineholm
# Processing Record 22 of Set 5 | placido de castro
# Processing Record 23 of Set 5 | along
# Processing Record 24 of Set 5 | buala
# Processing Record 25 of Set 5 | starachowice
# Processing Record 26 of Set 5 | ngunguru
# Processing Record 27 of Set 5 | coahuayana
# Processing Record 28 of Set 5 | anna paulowna
# Processing Record 29 of Set 5 | fort nelson
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | jardim
# Processing Record 35 of Set 5 | suez
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | legnica
# Processing Record 38 of Set 5 | shetpe
# Processing Record 39 of Set 5 | ternate
# Processing Record 40 of Set 5 | bubaque
# Processing Record 41 of Set 5 | geraldton
# Processing Record 42 of Set 5 | pangai
# Processing Record 43 of Set 5 | pitimbu
# Processing Record 44 of Set 5 | cabra
# Processing Record 45 of Set 5 | harigue
# City not found. Skipping...
# Processing Record 46 of Set 5 | manacapuru
# Processing Record 47 of Set 5 | siemiatycze
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | port hueneme
# Processing Record 50 of Set 5 | turukhansk
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | natal
# Processing Record 4 of Set 6 | bulungu
# Processing Record 5 of Set 6 | chumikan
# Processing Record 6 of Set 6 | nueva germania
# Processing Record 7 of Set 6 | verkhoyansk
# Processing Record 8 of Set 6 | carinhanha
# Processing Record 9 of Set 6 | puerto ayacucho
# Processing Record 10 of Set 6 | la gaulette
# City not found. Skipping...
# Processing Record 11 of Set 6 | bang saphan
# Processing Record 12 of Set 6 | datong
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | merrill
# Processing Record 15 of Set 6 | waipawa
# Processing Record 16 of Set 6 | broken hill
# Processing Record 17 of Set 6 | leghorn
# City not found. Skipping...
# Processing Record 18 of Set 6 | bahia blanca
# Processing Record 19 of Set 6 | sao domingos
# Processing Record 20 of Set 6 | lata
# Processing Record 21 of Set 6 | jacareacanga
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | norrtalje
# Processing Record 24 of Set 6 | agirish
# Processing Record 25 of Set 6 | owando
# Processing Record 26 of Set 6 | tiznit
# Processing Record 27 of Set 6 | kununurra
# Processing Record 28 of Set 6 | asau
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | zhigansk
# Processing Record 31 of Set 6 | davenda
# Processing Record 32 of Set 6 | najran
# Processing Record 33 of Set 6 | eyl
# Processing Record 34 of Set 6 | muros
# Processing Record 35 of Set 6 | dombarovskiy
# Processing Record 36 of Set 6 | pierre
# Processing Record 37 of Set 6 | kiruna
# Processing Record 38 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 6 | itahari
# City not found. Skipping...
# Processing Record 40 of Set 6 | sembe
# Processing Record 41 of Set 6 | cidreira
# Processing Record 42 of Set 6 | belmonte
# Processing Record 43 of Set 6 | forest grove
# Processing Record 44 of Set 6 | montemorelos
# Processing Record 45 of Set 6 | tautira
# Processing Record 46 of Set 6 | dudinka
# Processing Record 47 of Set 6 | sabang
# Processing Record 48 of Set 6 | lodwar
# Processing Record 49 of Set 6 | pozo colorado
# Processing Record 50 of Set 6 | tombouctou
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | pevek
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | bowen
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | pacific grove
# Processing Record 8 of Set 7 | yaan
# Processing Record 9 of Set 7 | xiaoweizhai
# Processing Record 10 of Set 7 | nagorsk
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 7 | teguldet
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | khuzhir
# Processing Record 16 of Set 7 | wanning
# Processing Record 17 of Set 7 | mersing
# Processing Record 18 of Set 7 | pisco
# Processing Record 19 of Set 7 | homer
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | amga
# Processing Record 22 of Set 7 | shubarshi
# Processing Record 23 of Set 7 | gidam
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | tyumentsevo
# Processing Record 26 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 7 | burns lake
# Processing Record 28 of Set 7 | guane
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | nuevo laredo
# Processing Record 31 of Set 7 | palma del rio
# Processing Record 32 of Set 7 | ovalle
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | pinheiro
# Processing Record 35 of Set 7 | taltal
# Processing Record 36 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 37 of Set 7 | penzance
# Processing Record 38 of Set 7 | joshimath
# Processing Record 39 of Set 7 | erenhot
# Processing Record 40 of Set 7 | sur
# Processing Record 41 of Set 7 | daru
# Processing Record 42 of Set 7 | slobodskoy
# Processing Record 43 of Set 7 | awjilah
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 7 | nouakchott
# Processing Record 47 of Set 7 | jalu
# Processing Record 48 of Set 7 | akhmeta
# Processing Record 49 of Set 7 | saldanha
# Processing Record 50 of Set 7 | yashkul
# Processing Record 1 of Set 8 | ucar
# Processing Record 2 of Set 8 | kerema
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | tilichiki
# Processing Record 5 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | fengzhen
# Processing Record 7 of Set 8 | santa maria del oro
# Processing Record 8 of Set 8 | port shepstone
# Processing Record 9 of Set 8 | villa corzo
# Processing Record 10 of Set 8 | zabid
# Processing Record 11 of Set 8 | brownwood
# Processing Record 12 of Set 8 | ekuvukeni
# Processing Record 13 of Set 8 | sigli
# Processing Record 14 of Set 8 | kampong chhnang
# Processing Record 15 of Set 8 | hof
# Processing Record 16 of Set 8 | baghdad
# Processing Record 17 of Set 8 | goundam
# Processing Record 18 of Set 8 | nichinan
# Processing Record 19 of Set 8 | simbahan
# Processing Record 20 of Set 8 | mattru
# Processing Record 21 of Set 8 | payo
# Processing Record 22 of Set 8 | hauterive
# Processing Record 23 of Set 8 | gravdal
# Processing Record 24 of Set 8 | takoradi
# Processing Record 25 of Set 8 | tabou
# Processing Record 26 of Set 8 | miercurea-ciuc
# Processing Record 27 of Set 8 | namatanai
# Processing Record 28 of Set 8 | marsh harbour
# Processing Record 29 of Set 8 | la peca
# Processing Record 30 of Set 8 | kirakira
# Processing Record 31 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 8 | mareeba
# Processing Record 33 of Set 8 | meulaboh
# Processing Record 34 of Set 8 | urumqi
# Processing Record 35 of Set 8 | bereda
# Processing Record 36 of Set 8 | nanlong
# Processing Record 37 of Set 8 | olafsvik
# Processing Record 38 of Set 8 | biltine
# Processing Record 39 of Set 8 | nyurba
# Processing Record 40 of Set 8 | pervomayskiy
# Processing Record 41 of Set 8 | ixtapa
# Processing Record 42 of Set 8 | poum
# Processing Record 43 of Set 8 | saint-leu
# Processing Record 44 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 8 | batemans bay
# Processing Record 46 of Set 8 | krasnokamensk
# Processing Record 47 of Set 8 | rocha
# Processing Record 48 of Set 8 | sao felix do xingu
# Processing Record 49 of Set 8 | arraial do cabo
# Processing Record 50 of Set 8 | gat
# Processing Record 1 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 9 | necochea
# Processing Record 3 of Set 9 | gorom-gorom
# Processing Record 4 of Set 9 | arroyo
# Processing Record 5 of Set 9 | broome
# Processing Record 6 of Set 9 | elk grove
# Processing Record 7 of Set 9 | alcudia
# Processing Record 8 of Set 9 | lugovoy
# Processing Record 9 of Set 9 | nanuet
# Processing Record 10 of Set 9 | puerto baquerizo moreno
# Processing Record 11 of Set 9 | honiara
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | muravlenko
# Processing Record 14 of Set 9 | cap-aux-meules
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | chupei
# City not found. Skipping...
# Processing Record 17 of Set 9 | monrovia
# Processing Record 18 of Set 9 | ayios vasilios
# Processing Record 19 of Set 9 | port augusta
# Processing Record 20 of Set 9 | usinsk
# Processing Record 21 of Set 9 | marzuq
# Processing Record 22 of Set 9 | black diamond
# Processing Record 23 of Set 9 | santa rosa
# Processing Record 24 of Set 9 | ghatampur
# Processing Record 25 of Set 9 | sisimiut
# Processing Record 26 of Set 9 | safaga
# Processing Record 27 of Set 9 | airai
# Processing Record 28 of Set 9 | fortuna
# Processing Record 29 of Set 9 | faanui
# Processing Record 30 of Set 9 | moron
# Processing Record 31 of Set 9 | linares
# Processing Record 32 of Set 9 | guaruja
# Processing Record 33 of Set 9 | adrar
# Processing Record 34 of Set 9 | lyngseidet
# Processing Record 35 of Set 9 | santa isabel do rio negro
# Processing Record 36 of Set 9 | yulara
# Processing Record 37 of Set 9 | evanston
# Processing Record 38 of Set 9 | namibe
# Processing Record 39 of Set 9 | gejiu
# Processing Record 40 of Set 9 | urucara
# Processing Record 41 of Set 9 | polyarnyy
# Processing Record 42 of Set 9 | angoche
# Processing Record 43 of Set 9 | kruisfontein
# Processing Record 44 of Set 9 | roald
# Processing Record 45 of Set 9 | kholtoson
# Processing Record 46 of Set 9 | bouar
# Processing Record 47 of Set 9 | saint-pierre
# Processing Record 48 of Set 9 | moncada
# Processing Record 49 of Set 9 | los zacatones
# Processing Record 50 of Set 9 | jumla
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21732/437264679.py in <module>
#      16         set_count += 1
#      17         record_count = 1
# ---> 18         time.sleep(60)
#      19
#      20     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Vestmannaeyjar  63.4427  -20.2734     34.72        75         100
# 1       Poronaysk  49.2167  143.1167     16.74        81          44
# 2         Mataura -46.1927  168.8643     67.48        35         100
# 3    Ponta Do Sol  32.6667  -17.1000     62.06        72          88
# 4         Iqaluit  63.7506  -68.5145    -16.31        68         100
# 5    Norman Wells  65.2820 -126.8329     -7.56        71         100
# 6        La Ronge  55.1001 -105.2842     14.25        79         100
# 7         Aracaju -10.9111  -37.0717     82.35        78          20
# 8      Bredasdorp -34.5322   20.0403     65.52        72          99
# 9           Ancud -41.8697  -73.8203     62.13        95           6
#
#    Wind Speed Country                 Date
# 0       31.29      IS  2022-02-14 01:35:06
# 1        9.71      RU  2022-02-14 01:35:07
# 2        2.75      NZ  2022-02-14 01:35:07
# 3        1.30      PT  2022-02-14 01:35:08
# 4        3.00      CA  2022-02-14 01:34:57
# 5        3.44      CA  2022-02-14 01:34:27
# 6        6.91      CA  2022-02-14 01:35:09
# 7       13.80      BR  2022-02-14 01:33:23
# 8        9.22      ZA  2022-02-14 01:35:10
# 9        2.26      CL  2022-02-14 01:35:10

# %%
len(city_data)
# Out:
# 411

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
